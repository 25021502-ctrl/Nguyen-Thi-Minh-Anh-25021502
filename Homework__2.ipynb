# %%
#Bai1
a, b = map(int,input().split())
print(a*b)
print((a+b)/2)
# Out:
# 20
# 4.5

# %%
#Bai2
import math
n = int(input())
print(2*math.pi*n)
print(math.pi*(n**2))
# Out:
# 25.132741228718345
# 50.26548245743669

# %%
#Bai3
a, b, c = map(int,input().split())
if a > b+c or b > a+c or c > a+b:
    print('Khong la ba canh cua mot tam giac')
else:
    if a == b == c:
        print("Tam giac deu")
    elif a == b or b == c or c == a:
        print("Tam giac can")
    elif a**2 + b**2 == c**2 or b**2 + c**2 == a**2 or c**2 + a**2 == b**2:
        print("Tam giac vuong")
    else:
        print("Tam giac thuong")
d = (a+b+c)/2
print("Dien tich tam giac:",(d*(d-a)*(d-b)*(d-c))**0.5)
print("Chu vi tam giac:",a+b+c)
# Out:
# Tam giac vuong
# Dien tich tam giac: 6.0
# Chu vi tam giac: 12

# %%
#Bai4
a, b = map(int,input().split())
if a == 0 and b == 0:
    print('phương trình vô số nghiệm')
elif a == 0 and b != 0:
    print('phương trình vô nghiệm')
else:
    print(-b/a)
# Out:
# -1.5

# %%
#Bai5
a, b, c = map(int,input().split())
delta = b**2 -4*a*c
if delta < 0:
    print('phương trình vô nghiệm')
elif delta == 0:
    print((-b + delta**0.5)/(2*a))
    print((-b - delta**0.5)/(2*a))
    print('phương trình có nghiệm kép')
else:
    print((-b + delta**0.5)/(2*a))
    print((-b - delta**0.5)/(2*a))
# Out:
# 2.0
# 2.0
# phương trình có nghiệm kép

# %%
#Bai6
a, b, c, d = map(int,input().split())
print(max(a, b, c, d))
# Out:
# 12345

# %%
#Bai7
a, b, c, d = map(int,input().split())
print(min(a, b, c, d))
# Out:
# 34

# %%
#Bai8

a1, b1, c1, a2, b2, c2 = map(float, input().split())

D = a1 * b2 - a2 * b1
Dx = c1 * b2 - c2 * b1
Dy = a1 * c2 - a2 * c1

if D != 0:
    x = Dx / D
    y = Dy / D
    print(f"Nghiệm của hệ là: x = {x}, y = {y}")
else:
    print("Hệ phương trình vô nghiệm hoặc vô số nghiệm.")
# Out:
# Nghiệm của hệ là: x = 0.25, y = 1.25

# %%
#Bai9
n = int(input())
gio = n // 3600
phut = (n % 3600) // 60
giay = n - gio*3600 - phut*60
print(gio,'giờ',phut,'phút',giay,'giây')
# Out:
# 3 giờ 25 phút 45 giây

# %%
#Bai10
a, b, R, x, y = map(int,input().split())
z = ((x - a)**2 + (y-b)**2)**0.5
if  z == R:
    print('Điểm nằm trên đường tròn')
else:
    print('Điểm không nằm trên đường tròn')
# Out:
# Điểm không nằm trên đường tròn

# %%
#Bai11
x, y = map(float,input().split())
print(x**y)
# Out:
# 64.0
